# %% [markdown]
# # **ESTADÍSTICA DESCRIPTIVA**

# %% [markdown]
# ![udem.png](data:image/png;base64,...)

# %% [markdown]
# ### A continuación realizaremos el Análisis Exploratorio de Datos AED con el fin de validar y verificar la información a través de la estadística descriptiva para posteriormente realizar inferencia sobre la población objetivo.
#
# https://www.kaggle.com/datasets/ranjeetjain3/seaborn-tips-dataset
#
# Food servers’ tips in restaurants may be influenced by many
# factors, including the nature of the restaurant, size of the party, and table
# locations in the restaurant. Restaurant managers need to know which factors
# matter when they assign tables to food servers. For the sake of staff morale,
# they usually want to avoid either the substance or the appearance of unfair
# treatment of the servers, for whom tips (at least in restaurants in the United
# States) are a major component of pay.
# In one restaurant, a food server recorded the following data on all cus-
# tomers they served during an interval of two and a half months in early 1990.
# The restaurant, located in a suburban shopping mall, was part of a national
# chain and served a varied menu. In observance of local law, the restaurant
# offered to seat in a non-smoking section to patrons who requested it. Each
# record includes a day and time, and taken together, they show the server’s
# work schedule.

# %% [markdown]
# #**1. Presentación de los datos**

# %% [markdown]
# ## **About Dataset: Freelancer Earnings and Job Trends Dataset**

# %% [markdown]
# Este conjunto de datos proporciona información exhaustiva sobre los ingresos de los autónomos y las tendencias laborales en varios sectores y categorías de competencias. Su objetivo es ayudar a las personas que buscan empleo, a los autónomos y a los investigadores a comprender los patrones de remuneración y la demanda en la economía colaborativa.
# Limpieza y preprocesamiento de datos: Se aplicaron los siguientes pasos de preprocesamiento para garantizar la calidad de los datos:
# •	Eliminación de entradas duplicadas
# •	Normalización de los valores monetarios a USD
# •	Normalización de los nombres de las categorías de empleo
# •	Relleno de los valores que faltaban utilizando [describa su enfoque]
# •	Filtrado de los valores atípicos basándose en [sus criterios].

# %%
# %pip install kagglehub
# %pip install pandas

# %%
import kagglehub
import shutil

# Download latest version
path = kagglehub.dataset_download("ranjeetjain3/seaborn-tips-dataset")

print("Path to dataset files:", path)

# Copiar el dataset descargado a la ruta que quieras
destino = "C:/Users/marin/OneDrive/Desktop/UdeM/Nube/Propinas/MLOPS_Project/data"
shutil.copytree(path, destino, dirs_exist_ok=True)

print("Dataset guardado en:", destino)
# Out:
# Path to dataset files: C:\Users\marin\.cache\kagglehub\datasets\ranjeetjain3\seaborn-tips-dataset\versions\1
# Dataset guardado en: C:/Users/marin/OneDrive/Desktop/UdeM/Nube/Propinas/MLOPS_Project/data

# %% [markdown]
# # **2. Cargar el conjunto de datos**

# %%
import pandas as pd

# Leer el archivo con pandas
datos = pd.read_csv("C:/Users/marin/OneDrive/Desktop/UdeM/Nube/Propinas/MLOPS_Project/data/tips.csv")

# Mostrar los 10 primeros registros del DataFrame
print()
datos.head(10)
# Out:
#      <input type="file" id="files-b9742f5e-f539-4b3f-b9b0-a5734d427582" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b9742f5e-f539-4b3f-b9b0-a5734d427582">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Cargar las librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt #Graficar
# %matplotlib inline
import seaborn as sns
from collections import Counter
import math

# %%
#Revisando estructura de los datos
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# ## **3. Medidas descriptivas**

# %% [markdown]
# ## **3.1 Medidas de tendencia central**
#
# Son medidas que nos ayudan a resumir una gran cantidad de información en un solo numero
#
# ## **Media:**
# Es el promedio de todos los datos, puede ser susceptible a valores atípicos
#
# **Media** = $$ \frac{1}{N} \sum_{i=1}^N x_i  $$
#
# ## **Mediana:**
# Es el dato central es decir tiene la misa cantidad de datos a su izquierda y derecha, no es lo mismo que la media
#
# ### **Mediana(n=impar)** = $$ x_{(n+1)/2}^{\text{ordered}} $$
#
# ### **Mediana(n=par)** = $$ \frac{x_{(n/2)}^{\text{ordered}} + x_{(n/2)+1}^{\text{ordered}}}{2} $$
#
# ## **Moda:**
# Es el dato que mas se repite, la moda no aplica para datos numéricos continuos
#
# ### **Moda** = $$ x_k $$ donde $$ \text{Freq}(x_k) = \max{(\text{Freq}(x_i))} $$

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
#total_bill

#Media
media_total_bill =datos['total_bill'].mean()
print("Media del número de proyectos terminados exitosamente por los freelancer es:", media_total_bill)
#Mediana
mediana_Job_Completed =datos['total_bill'].median()
print(f"Mediana del número de proyectos terminados exitosamente por los freelancer es: {mediana_Job_Completed}")
#Moda
moda_Job_Completed = datos['total_bill'].mode()
print("La Moda del número de proyectos terminados exitosamente por los freelancer es:", moda_Job_Completed)
# Out:
# Media del número de proyectos terminados exitosamente por los freelancer es: 19.78594262295082
# Mediana del número de proyectos terminados exitosamente por los freelancer es: 17.795
# La Moda del número de proyectos terminados exitosamente por los freelancer es: 0    13.42
# Name: total_bill, dtype: float64

# %%
#Earnings_USD

#Media
media_Earnings_USD =datos['Earnings_USD'].mean()
print("Media de las ganancias de los freelancer es:", media_Earnings_USD)
#Mediana
mediana_Earnings_USD =datos['Earnings_USD'].median()
print(f"Mediana de las ganancias de los freelancer es: {mediana_Earnings_USD}")
#Moda
moda_Earnings_USD = datos['Earnings_USD'].mode()
print("La Moda de las ganancias de los freelancer es:", moda_Earnings_USD)
# Out:
# Media de las ganancias de los freelancer es: 5017.566666666667
# Mediana de las ganancias de los freelancer es: 5048.0
# La Moda de las ganancias de los freelancer es: 0      498
# 1      649
# 2     2211
# 3     2298
# 4     2398
# 5     3286
# 6     3994
# 7     4773
# 8     5793
# 9     8824
# 10    9914
# Name: Earnings_USD, dtype: int64

# %% [markdown]
# Es importante resaltar que si no hay valores que se repiten, todos los datos son considerados la moda

# %% [markdown]
# # **3.2 Medidas de variabilidad**

# %%
#Job_Completed

#Varianza
varianza_Job_Completed =datos['Job_Completed'].var()
print("La varianza del número de proyectos terminados exitosamente por los freelancer es: ", varianza_Job_Completed)
#Desviación estandar
desvest_Job_Completed =np.sqrt(varianza_Job_Completed)
print("La desviación estándar del número de proyectos terminados exitosamente por los freelancer es:", desvest_Job_Completed)
#Coeficiente de variación
CV_Job_Completed=(desvest_Job_Completed/varianza_Job_Completed)*100
print("El coeficiente de variación del número de proyectos terminados exitosamente por los freelanceres:", CV_Job_Completed)
#Rango
Rango_Job_Completed=datos['Job_Completed'].max()-datos['Job_Completed'].min()
print("El rango del número de proyectos terminados exitosamente por los freelancer es:", Rango_Job_Completed)
# Out:
# La varianza del número de proyectos terminados exitosamente por los freelancer es:  7306.962025233198
# La desviación estándar del número de proyectos terminados exitosamente por los freelancer es: 85.48076991483639
# El coeficiente de variación del número de proyectos terminados exitosamente por los freelanceres: 1.1698537589171105
# El rango del número de proyectos terminados exitosamente por los freelancer es: 294

# %%
#Earnings_USD
#Varianza
varianza_Earnings_USD =datos['Earnings_USD'].var()
print("La varianza de las ganancias de los freelancer es: ", varianza_Earnings_USD)
#Desviación estandar
desvest_Earnings_USD =np.sqrt(varianza_Earnings_USD)
print("La desviación estándar de las ganancias de los freelancer es:", desvest_Earnings_USD)
#Coeficiente de variación
CV_Earnings_USD=(desvest_Earnings_USD/varianza_Earnings_USD)*100
print("El coeficiente de variación de las ganancias de los freelancer es:", CV_Job_Completed)
#Rango
Rango_Earnings_USD=datos['Earnings_USD'].max()-datos['Earnings_USD'].min()
print("El rango de las ganancias de los freelancer es:", Rango_Earnings_USD)
# Out:
# La varianza de las ganancias de los freelancer es:  8563114.156405026
# La desviación estándar de las ganancias de los freelancer es: 2926.279917643735
# El coeficiente de variación de las ganancias de los freelancer es: 1.1698537589171105
# El rango de las ganancias de los freelancer es: 9940

# %% [markdown]
# # **3.3 Medidas de forma**

# %%
#Job_Completed

#Coeficiente de Asimetría
Asimetria_Job_Completed=datos['Job_Completed'].skew()
print("El coeficiente de asimetría del número de proyectos terminados exitosamente por los freelancer es:", Asimetria_Job_Completed)
#Coeficiente de Kurtosis
Kurtosis_Job_Completed=datos['Job_Completed'].kurt()
print("El coeficiente del número de proyectos terminados exitosamente por los freelancer es:", Kurtosis_Job_Completed)
# Out:
# El coeficiente de asimetría del número de proyectos terminados exitosamente por los freelancer es: 0.0022058468260943024
# El coeficiente del número de proyectos terminados exitosamente por los freelancer es: -1.2054324946362531

# %%
#Earnings_USD

#Coeficiente de Asimetría
Asimetria_Earnings_USD=datos['Earnings_USD'].skew()
print("El coeficiente de asimetría de las ganancias de los freelancer es:", Asimetria_Earnings_USD)
#Coeficiente de Kurtosis
Kurtosis_Earnings_USD=datos['Earnings_USD'].kurt()
print("El coeficiente de las ganancias de los freelancer es:", Kurtosis_Earnings_USD)
# Out:
# El coeficiente de asimetría de las ganancias de los freelancer es: -0.007578935317065122
# El coeficiente de las ganancias de los freelancer es: -1.210607962804872

# %% [markdown]
# # **3.4 Medidas de posición**

# %%
#Job_Completed

#Tercios
Q1= np.percentile(datos['Job_Completed'], 33)
Q2= np.percentile(datos['Job_Completed'], 66)
print(Q1,Q2)
print("El 33% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a:", Q1)
print("El 66% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a:", Q2)
# Out:
# 100.17000000000007 199.0
# El 33% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a: 100.17000000000007
# El 66% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a: 199.0

# %%
#Job_Completed
#Cuartiles
Q1= np.percentile(datos['Job_Completed'], 25)
Q2= np.percentile(datos['Job_Completed'], 50)
Q3= np.percentile(datos['Job_Completed'], 75)
print(Q1,Q2,Q3)
print("El 25% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a:", Q1)
print("El 50% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a:", Q2)
print("El 75% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a:", Q3)
# Out:
# 76.0 149.0 225.0
# El 25% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a: 76.0
# El 50% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a: 149.0
# El 75% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a: 225.0

# %%
#Job_Completed

#Quintiles
Q1= np.percentile(datos['Job_Completed'], 20)
Q2= np.percentile(datos['Job_Completed'], 40)
Q3= np.percentile(datos['Job_Completed'], 60)
Q4= np.percentile(datos['Job_Completed'], 80)
print(Q1,Q2,Q3,Q4)
print("El 20% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a:", Q1)
print("El 40% del número de proyectos terminados exitosamente por los freelancer son son menores o iguales a:", Q2)
print("El 60% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a:", Q3)
print("El 80% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a:", Q4)
# Out:
# 63.0 123.0 181.0 239.0
# El 20% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a: 63.0
# El 40% del número de proyectos terminados exitosamente por los freelancer son son menores o iguales a: 123.0
# El 60% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a: 181.0
# El 80% del número de proyectos terminados exitosamente por los freelancer son menores o iguales a: 239.0

# %%
#Earnings_USD

#Tercios
Q1= np.percentile(datos['Earnings_USD'], 33)
Q2= np.percentile(datos['Earnings_USD'], 66)
print(Q1,Q2)
print("El 33% de las ganancias de los freelancer son menores o iguales a:", Q1)
print("El 66% de las ganancias de los freelancer son menores o iguales a:", Q2)
# Out:
# 3333.34 6588.720000000001
# El 33% de las ganancias de los freelancer son menores o iguales a: 3333.34
# El 66% de las ganancias de los freelancer son menores o iguales a: 6588.720000000001

# %%
#Earnings_USD
#Cuartiles
Q1= np.percentile(datos['Earnings_USD'], 25)
Q2= np.percentile(datos['Earnings_USD'], 50)
Q3= np.percentile(datos['Earnings_USD'], 75)
print(Q1,Q2,Q3)
print("El 25% de las ganancias de los freelancer son menores o iguales a:", Q1)
print("El 50% de las ganancias de los freelancer son menores o iguales a:", Q2)
print("El 75% de las ganancias de los freelancer son menores o iguales a:", Q3)
# Out:
# 2419.0 5048.0 7608.25
# El 25% de las ganancias de los freelancer son menores o iguales a: 2419.0
# El 50% de las ganancias de los freelancer son menores o iguales a: 5048.0
# El 75% de las ganancias de los freelancer son menores o iguales a: 7608.25

# %%
#Earnings_USD

#Quintiles
Q1= np.percentile(datos['Earnings_USD'], 20)
Q2= np.percentile(datos['Earnings_USD'], 40)
Q3= np.percentile(datos['Earnings_USD'], 60)
Q4= np.percentile(datos['Earnings_USD'], 80)
print(Q1,Q2,Q3,Q4)
print("El 20% de las ganancias de los freelancer son menores o iguales a:", Q1)
print("El 40% de las ganancias de los freelancer son son menores o iguales a:", Q2)
print("El 60% de las ganancias de los freelancer son menores o iguales a:", Q3)
print("El 80% de las ganancias de los freelancer son menores o iguales a:", Q4)
# Out:
# 1919.4 3998.0 6034.4 8114.0
# El 20% de las ganancias de los freelancer son menores o iguales a: 1919.4
# El 40% de las ganancias de los freelancer son son menores o iguales a: 3998.0
# El 60% de las ganancias de los freelancer son menores o iguales a: 6034.4
# El 80% de las ganancias de los freelancer son menores o iguales a: 8114.0

# %%
#Realizando una descripción rápida de las variables numéricas
datos.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# #**4. Tablas y gráficos descriptivos univariados**

# %% [markdown]
# # 4.1 Tablas y gráficas para una variable continua: para esta sección elegimos los trabajos completados y las ganancias

# %%
#Tabla de frecuencias con los intervalos automáticos

def tabla_frecuencia(datos):
    columna = datos['Job_Completed']  # Seleccionar la columna de interés
    n = len(columna)  # Cantidad de datos
    k = math.ceil(1 + math.log2(n))  # Regla de Sturges
    min_val, max_val = min(columna), max(columna)
    rango = max_val - min_val
    amplitud = rango / k  # Amplitud de los intervalos

    # Definir los intervalos
    bins = np.linspace(min_val, max_val, k + 1)

    # Calcular frecuencias
    frecuencias, _ = np.histogram(columna, bins)

    # Calcular frecuencias acumuladas
    frec_acumulada = np.cumsum(frecuencias)

    # Calcular frecuencia relativa
    frec_relativa = frecuencias / n

    # Calcular frecuencia relativa acumulada
    frec_rel_acumulada = np.cumsum(frec_relativa)

    # Crear tabla de frecuencias
    tabla = pd.DataFrame({
        'Intervalo': [f'[{bins[i]:.2f}, {bins[i+1]:.2f})' for i in range(len(bins)-1)],
        'Frecuencia': frecuencias,
        'Frec. Acumulada': frec_acumulada,
        'Frec. Relativa': frec_relativa,
        'Frec. Rel. Acumulada': frec_rel_acumulada
    })

    return tabla

# Aplicar función al DataFrame
resultado = tabla_frecuencia(datos)
print(resultado)
# Out:
#            Intervalo  Frecuencia  Frec. Acumulada  Frec. Relativa  \
# 0      [5.00, 29.50)         181              181        0.092821
# 1     [29.50, 54.00)         153              334        0.078462
# 2     [54.00, 78.50)         175              509        0.089744
# 3    [78.50, 103.00)         149              658        0.076410
# 4   [103.00, 127.50)         164              822        0.084103
# 5   [127.50, 152.00)         173              995        0.088718
# 6   [152.00, 176.50)         145             1140        0.074359
# 7   [176.50, 201.00)         158             1298        0.081026
# 8   [201.00, 225.50)         172             1470        0.088205
# 9   [225.50, 250.00)         156             1626        0.080000
# 10  [250.00, 274.50)         162             1788        0.083077
# 11  [274.50, 299.00)         162             1950        0.083077
#
#     Frec. Rel. Acumulada
# 0               0.092821
# 1               0.171282
# 2               0.261026
# ...

# %%
#Tabla de frecuencias con los intervalos automáticos

def tabla_frecuencia(datos):
    columna = datos['Earnings_USD']  # Seleccionar la columna de interés
    n = len(columna)  # Cantidad de datos
    k = math.ceil(1 + math.log2(n))  # Regla de Sturges
    min_val, max_val = min(columna), max(columna)
    rango = max_val - min_val
    amplitud = rango / k  # Amplitud de los intervalos

    # Definir los intervalos
    bins = np.linspace(min_val, max_val, k + 1)

    # Calcular frecuencias
    frecuencias, _ = np.histogram(columna, bins)

    # Calcular frecuencias acumuladas
    frec_acumulada = np.cumsum(frecuencias)

    # Calcular frecuencia relativa
    frec_relativa = frecuencias / n

    # Calcular frecuencia relativa acumulada
    frec_rel_acumulada = np.cumsum(frec_relativa)

    # Crear tabla de frecuencias
    tabla = pd.DataFrame({
        'Intervalo': [f'[{bins[i]:.2f}, {bins[i+1]:.2f})' for i in range(len(bins)-1)],
        'Frecuencia': frecuencias,
        'Frec. Acumulada': frec_acumulada,
        'Frec. Relativa': frec_relativa,
        'Frec. Rel. Acumulada': frec_rel_acumulada
    })

    return tabla

# Aplicar función al DataFrame
resultado = tabla_frecuencia(datos)
print(resultado)
# Out:
#              Intervalo  Frecuencia  Frec. Acumulada  Frec. Relativa  \
# 0      [51.00, 879.33)         177              177        0.090769
# 1    [879.33, 1707.67)         177              354        0.090769
# 2   [1707.67, 2536.00)         159              513        0.081538
# 3   [2536.00, 3364.33)         140              653        0.071795
# 4   [3364.33, 4192.67)         150              803        0.076923
# 5   [4192.67, 5021.00)         169              972        0.086667
# 6   [5021.00, 5849.33)         158             1130        0.081026
# 7   [5849.33, 6677.67)         179             1309        0.091795
# 8   [6677.67, 7506.00)         137             1446        0.070256
# 9   [7506.00, 8334.33)         167             1613        0.085641
# 10  [8334.33, 9162.67)         161             1774        0.082564
# 11  [9162.67, 9991.00)         176             1950        0.090256
#
#     Frec. Rel. Acumulada
# 0               0.090769
# 1               0.181538
# ...

# %%
#El histograma de frecuencias
plt.bar(resultado['Intervalo'], resultado['Frecuencia'], align='center')
plt.xticks(rotation=45)
plt.xlabel('Intervalos')
plt.ylabel('Frecuencia')
plt.title('Histograma de Frecuencias')
plt.show()

# %%
#Otra visualización para el Histograma de frecuencias
sns.histplot(datos['Job_Completed'])
# Out:
# <Axes: xlabel='Job_Completed', ylabel='Count'>

# %%
#Otra visualización para el Histograma de frecuencias
sns.histplot(datos['Earnings_USD'])
# Out:
# <Axes: xlabel='Earnings_USD', ylabel='Count'>

# %%
#Gráfico de densidad
sns.kdeplot(datos['Earnings_USD'], shade=True)
# Out:
# /tmp/ipython-input-23-1107195025.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(datos['Earnings_USD'], shade=True)
# <Axes: xlabel='Earnings_USD', ylabel='Density'>

# %%
#Diagrama de Densidad con histograma
sns.displot(datos['Job_Completed'], kde=True)

# %%
#Diagrama de Densidad con histograma
sns.displot(datos['Earnings_USD'], kde=True)

# %%
#El gráfico de caja y bigotes
sns.boxplot(datos['Job_Completed'],orient="h")
# Out:
# <Axes: xlabel='Job_Completed'>

# %%
#El gráfico de caja y bigotes
sns.boxplot(datos['Earnings_USD'],orient="h")
# Out:
# <Axes: xlabel='Earnings_USD'>

# %%
#El gráfico de caja y bigotes por de trabajos completados por categoria de trabajos
sns.boxplot(data=datos, x=datos['Job_Completed'], y=datos['Job_Category'])
# Out:
# <Axes: xlabel='Job_Completed', ylabel='Job_Category'>

# %%
#El gráfico de caja y bigotes de ganancias de los freelancers por categoría de trabajos
sns.boxplot(data=datos, x=datos['Earnings_USD'], y=datos['Job_Category'])
# Out:
# <Axes: xlabel='Earnings_USD', ylabel='Job_Category'>

# %%
#El gráfico de caja y bigotes por Trabajos completados por Categoria de trabajo
sns.boxplot(data=datos, x=datos['Job_Success_Rate'], y=datos['Job_Category'])
# Out:
# <Axes: xlabel='Job_Success_Rate', ylabel='Job_Category'>

# %% [markdown]
# # 4.2 Tablas y gráficas para una variable categórica: para esta sección elegimos las regiones donde están los clientes

# %%
#Gráficos de barras
print(datos['Client_Region'].value_counts())
print("\n")
print(datos['Client_Region'].value_counts(normalize=True))


print("\nGrafico Barras \n")
datos['Client_Region'].value_counts(normalize=True).plot.barh()
plt.show()
# Out:
# Client_Region
# Australia      298
# USA            292
# Middle East    291
# Asia           281
# UK             280
# Europe         262
# Canada         246
# Name: count, dtype: int64
#
#
# Client_Region
# Australia      0.152821
# USA            0.149744
# Middle East    0.149231
# Asia           0.144103
# UK             0.143590
# Europe         0.134359
# Canada         0.126154
# Name: proportion, dtype: float64
#
# Grafico Barras

# %%
#Gráfico de torta
print(datos['Client_Region'].value_counts(normalize=True))
datos['Client_Region'].value_counts().plot.pie()
plt.show()
# Out:
# Client_Region
# Australia      0.152821
# USA            0.149744
# Middle East    0.149231
# Asia           0.144103
# UK             0.143590
# Europe         0.134359
# Canada         0.126154
# Name: proportion, dtype: float64

# %% [markdown]
# # **5. Medidas y gráficas descriptivas multivariadas**

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
#Separar las variables continuas de las demás
continuas=datos[["total_bill","tip","size"]]

# %%
#Gráfico exploratorio por pares de variables
sns.pairplot(continuas)

# %%
#La matriz de correlaciones
correlation_matrix=continuas.corr()
continuas.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(correlation_matrix, annot=True)
# Out:
# <Axes: >

# %%
print(sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", center=0))
# Out:
# Axes(0.125,0.11;0.62x0.77)

# %%
print(sns.heatmap(correlation_matrix, annot=True, cmap="Blues", center=0))
# Out:
# Axes(0.125,0.11;0.62x0.77)
